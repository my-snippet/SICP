-- %%
zipWith' :: (a -> b -> c) -> [a] -> [b] -> [c]  
zipWith' _ [] _ = []  
zipWith' _ _ [] = []  
zipWith' f (x:xs) (y:ys) = f x y : zipWith' f xs ys

-- %%
zipWith' (*) (replicate 5 2) [1..]
-- Out:
-- [2,4,6,8,10]

-- %%
 zipWith' (zipWith' (*)) [[1,2,3],[3,5,6],[2,3,4]] [[3,2,2],[3,4,5],[5,4,3]]
-- Out:
-- [[3,4,6],[9,20,30],[10,12,12]]

-- %%
 zipWith' (*) [[1,2,3],[3,5,6],[2,3,4]] [[3,2,2],[3,4,5],[5,4,3]]
-- Out:
-- Non type-variable argument in the constraint: Num [t]
-- (Use FlexibleContexts to permit this)
-- When checking that ‘it’ has the inferred type
--   it :: forall t. (Num t, Num [t]) => [[t]]

-- %% [markdown]
-- (a -> b -> c) -> (b -> a -> c) is the same as (a -> b -> c) -> (b -> (a -> c)), which is the same as (a -> b -> c) -> b -> a -> c. We wrote that g x y = f y x.

-- %%
flip' :: (a -> b -> c) -> b -> a -> c  
flip' f y x = f x y

-- %%
flip' zip [1,2,3,4,5] "hello"
-- Out:
-- [('h',1),('e',2),('l',3),('l',4),('o',5)]

-- %%
zip [1..5] "hello"
-- Out:
-- [(1,'h'),(2,'e'),(3,'l'),(4,'l'),(5,'o')]

-- %%
map :: (a -> b) -> [a] -> [b]  
map _ [] = []  
map f (x:xs) = f x : map f xs

-- %%
map (+2) [1..5]
-- Out:
-- [3,4,5,6,7]

-- %%
map ("hi, " ++) ["aloha", "hawai"]
-- Out:
-- ["hi, aloha","hi, hawai"]

-- %%
map (replicate 3) [3..6]
-- Out:
-- [[3,3,3],[4,4,4],[5,5,5],[6,6,6]]

-- %%
map fst [(1,2),(3,5),(6,3),(2,6),(2,5)]
-- Out:
-- [1,3,6,2,2]

-- %%
 map (map (^2)) [[1,2],[3,4,5,6],[7,8]]
-- Out:
-- [[1,4],[9,16,25,36],[49,64]]

-- %%
 map (^2) [(1,2),(3,4,5,6),(7,8)]
-- Out:
-- Couldn't match expected type ‘(t, t1)’ with actual type ‘(Integer, Integer, Integer, Integer)’
-- Relevant bindings include it :: [(t, t1)] (bound at <interactive>:1:1)
-- In the expression: (3, 4, 5, 6)
-- In the second argument of ‘map’, namely ‘[(1, 2), (3, 4, 5, 6), (7, 8)]’
-- In the expression: map (^ 2) [(1, 2), (3, 4, 5, 6), (7, 8)]

-- %%
[x+3 | x <- [1,5,3,1,6]]
-- Out:
-- [4,8,6,4,9]

-- %%
map (+3) [1,5,3,1,6]
-- Out:
-- [4,8,6,4,9]

-- %%
filter :: (a -> Bool) -> [a] -> [a]  
filter _ [] = []  
filter p (x:xs)   
    | p x       = x : filter p xs  
    | otherwise = filter p xs

-- %%
filter (>=3) [1,2,3,4,5]
-- Out:
-- [3,4,5]

-- %%
filter even [1..10]
-- Out:
-- [2,4,6,8,10]

-- %%
let notNull x = not (null x) in filter notNull [[1,2,3],[],[3,4,5],[2,2],[],[],[]]
-- Out:
-- [[1,2,3],[3,4,5],[2,2]]

-- %%
filter (`elem` ['a'..'z']) "u LaUgH aT mE BeCaUsE I aM diFfeRent"
-- Out:
-- "uagameasadifeent"

-- %%
filter (`elem` ['a'..'Z']) "u LaUgH aT mE BeCaUsE I aM diFfeRent"
-- Out:
-- ""

-- %%
quicksort :: (Ord a) => [a] -> [a]    
quicksort [] = []    
quicksort (x:xs) =     
    let smallerSorted = quicksort (filter (<=x) xs)  
        biggerSorted = quicksort (filter (>x) xs)   
    in  smallerSorted ++ [x] ++ biggerSorted

-- %%
quicksort [1,5,9,2,4,8]
-- Out:
-- [1,2,4,5,8,9]

-- %%
largestDivisible :: (Integral a) => a  
largestDivisible = head (filter p [100000,99999..])  
    where p x = x `mod` 3829 == 0

-- %%
largestDivisible
-- Out:
-- 99554

-- %%
sum (takeWhile (<10000) (filter odd (map (^2) [1..])))
-- Out:
-- 166650

-- %%
sum (takeWhile (<10000) [n^2 | n <- [1..], odd (n^2)])
-- Out:
-- 166650

-- %%
takeWhile (<10000) (filter odd (map (^2) [1..]))
-- Out:
-- [1,9,25,49,81,121,169,225,289,361,441,529,625,729,841,961,1089,1225,1369,1521,1681,1849,2025,2209,2401,2601,2809,3025,3249,3481,3721,3969,4225,4489,4761,5041,5329,5625,5929,6241,6561,6889,7225,7569,7921,8281,8649,9025,9409,9801]

-- %%
chain :: (Integral a) => a -> [a]  
chain 1 = [1]  
chain n  
    | even n =  n:chain (n `div` 2)  
    | odd n  =  n:chain (n*3 + 1)

-- %%
chain 3
-- Out:
-- [3,10,5,16,8,4,2,1]

-- %%
chain 1
-- Out:
-- [1]

-- %%
chain 20
-- Out:
-- [20,10,5,16,8,4,2,1]

-- %%
numLongChains :: Int  
numLongChains = length (filter isLong (map chain [1..100]))  
    where isLong xs = length xs > 15

-- %%
numLongChains
-- Out:
-- 66

-- %%
flip' :: (a -> b -> c) -> b -> a -> c  
flip' f = \x y -> f y x
-- Out:
-- Line 2: Avoid lambda
-- Found:
-- \ x y -> f y x
-- Why not:
-- flip f

-- %%
:t foldl1
-- Out:
-- foldl1 :: forall (t :: * -> *) a. Foldable t => (a -> a -> a) -> t a -> a

-- %%
sum' :: (Num a) => [a] -> a  
sum' = foldl (+) 0
-- Out:
-- Line 2: Use sum
-- Found:
-- foldl (+) 0
-- Why not:
-- sum

-- %% [markdown]
-- That works Because the functions are curried.

-- %%
sum' [1,2,3]
-- Out:
-- 6

-- %%
map' :: (a -> b) -> [a] -> [b]  
map' f xs = foldr (\x acc -> f x : acc) [] xs

-- %%
map' (+4) [1..5]
-- Out:
-- [5,6,7,8,9]

-- %% [markdown]
-- continue from foldl foldr ( What is different with foldl1, foldr1 ) ?

-- %%
flip zip [1,2,3] "456"
-- Out:
-- Line 1: Redundant flip
-- Found:
-- flip zip [1, 2, 3] "456"
-- Why not:
-- zip "456" [1, 2, 3]
-- [('4',1),('5',2),('6',3)]

-- %%
reverse' :: [a] -> [a]
reverse' = foldl (flip (:)) []

-- %%
reverse' [1,2,3,4]
-- Out:
-- [4,3,2,1]

-- %%
flip (:) "ab" "cd"
-- Out:
-- Line 1: Redundant flip
-- Found:
-- flip (:) "ab" "cd"
-- Why not:
-- (:) "cd" "ab"
-- Couldn't match expected type ‘Char’ with actual type ‘String’
-- In the third argument of ‘flip’, namely ‘"cd"’
-- In the expression: flip (:) "ab" "cd"
-- In an equation for ‘it’: it = flip (:) "ab" "cd"

-- %%
0:[1,2,3]
-- Out:
-- [0,1,2,3]

-- %%
scanl1 (+) [1,2,3,4,5]
-- Out:
-- [1,3,6,10,15]

-- %%
scanl1 (\acc x -> if x > acc then x else acc) [3,4,5,3,7,9,2,1]
-- Out:
-- [3,4,5,5,7,9,9,9]

-- %%
scanl (flip (:)) [] [3,4,5,3,7,9,2,1]
-- Out:
-- [[],[3],[4,3],[5,4,3],[3,5,4,3],[7,3,5,4,3],[9,7,3,5,4,3],[2,9,7,3,5,4,3],[1,2,9,7,3,5,4,3]]

-- %%
sqrtSums :: Int  
sqrtSums = length (takeWhile (<1000) (scanl1 (+) (map sqrt [1..]))) + 1

-- %% [markdown]
-- ```scanl1 makes a list satisfying a condition of takeWhile
-- So in this case, we can't use foldl1```

-- %%
sqrtSums
-- Out:
-- 131

-- %%
takeWhile (<10) [1..]
-- Out:
-- [1,2,3,4,5,6,7,8,9]

-- %%
takeWhile (<3) $ map sqrt [1..]
-- Out:
-- [1.0,1.4142135623730951,1.7320508075688772,2.0,2.23606797749979,2.449489742783178,2.6457513110645907,2.8284271247461903]

-- %%
foldl1 (+) (map sqrt [1..5])
-- Out:
-- Line 1: Use sum
-- Found:
-- foldl1 (+)
-- Why not:
-- sum
-- 8.382332347441762

-- %%
:t ($)
-- Out:
-- ($) :: forall a b. (a -> b) -> a -> b

-- %%
sum $ filter (> 10) $ map (*2) [2..10]
-- Out:
-- 80

-- %% [markdown]
-- ```But apart from getting rid of parentheses, $ means that function application can be treated just like another function.```

-- %%
map ($ 3) [(4+), (10*), (^2), sqrt]
-- Out:
-- [7.0,30.0,9.0,1.7320508075688772]

-- %%
:t (.)
-- Out:
-- (.) :: forall b c a. (b -> c) -> (a -> b) -> a -> c

-- %%
map (negate . abs) [5,-3,-6,7,-3,2,-19,24]
-- Out:
-- [-5,-3,-6,-7,-3,-2,-19,-24]

-- %%
 map (negate . sum . tail) [[1..5],[3..6],[1..7]]
-- Out:
-- [-14,-15,-27]

-- %%
replicate 10 . product . map (*3) . zipWith max [1,2,3,4,5] $ [4,5,6,7,8]
-- Out:
-- [1632960,1632960,1632960,1632960,1632960,1632960,1632960,1632960,1632960,1632960]

-- %%
sum' :: (Num a) => [a] -> a     
sum' = foldl (+) 0
-- Out:
-- Line 2: Use sum
-- Found:
-- foldl (+) 0
-- Why not:
-- sum

-- %%
fn = ceiling . negate . tan . cos . max 50

-- %%
oddSquareSum :: Integer  
oddSquareSum =   
    let oddSquares = filter odd $ map (^2) [1..]  
        belowLimit = takeWhile (<10000) oddSquares  
    in  sum belowLimit

-- %%
oddSquareSum
-- Out:
-- 166650
